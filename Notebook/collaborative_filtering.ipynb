# %%
import pandas as pd
df=pd.read_csv(r"../Data/cleaned_data.csv")
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
import random

# %%
merged_df=pd.read_csv("../Data/merged_user_interaction_data.csv")

# %%
# --- Your existing userwise_split function ---
def userwise_split(df, test_frac=0.2, seed=42):
    train_rows, test_rows = [], []
    grouped = df.groupby('user_id')
    for user_id, group in grouped:
        if len(group) < 2:
            train_rows.append(group)
            continue
        train, test = train_test_split(group, test_size=test_frac, random_state=seed)
        train_rows.append(train)
        test_rows.append(test)
    train_df = pd.concat(train_rows).reset_index(drop=True)
    test_df = pd.concat(test_rows).reset_index(drop=True)
    return train_df, test_df

# --- Hybrid recommendation function ---
def recommend_items_hybrid(user_id, train_matrix, user_sim, item_sim, top_k=5, alpha=0.5):
    if user_id not in train_matrix.index:
        return []
    user_vec = train_matrix.loc[user_id]
    interacted = user_vec[user_vec > 0].index.tolist()
    if not interacted:
        return []

    # User-based prediction
    sim_scores = user_sim.loc[user_id].drop(user_id, errors='ignore')
    weighted_user_sum = (sim_scores.values.reshape(-1,1) * train_matrix.loc[sim_scores.index]).sum(axis=0)
    weighted_user_sum = pd.Series(weighted_user_sum, index=train_matrix.columns)

    # Item-based prediction
    weighted_item_sum = pd.Series(0, index=train_matrix.columns, dtype=float)
    for item in interacted:
        weighted_item_sum += item_sim.loc[item]
    weighted_item_sum = weighted_item_sum.drop(interacted, errors='ignore')

    # Combine
    combined_scores = (alpha * weighted_user_sum) + ((1 - alpha) * weighted_item_sum)
    recommended = combined_scores.sort_values(ascending=False).head(top_k).index.tolist()
    return recommended

# --- Precision and Recall functions ---
def precision_at_k(recommended, relevant, k):
    if not relevant:
        return 0.0
    return len(set(recommended[:k]) & relevant) / k

def recall_at_k(recommended, relevant, k):
    if not relevant:
        return 0.0
    return len(set(recommended[:k]) & relevant) / len(relevant)

# ----------------------------------
# Suppose you have `merged_df` with columns ["user_id", "product_id", "score", ...]
# Example usage:

# 1. Split data
train_df, test_df = userwise_split(merged_df)

# 2. Create user-item rating matrix from train data
user_item_matrix = train_df.pivot_table(index='user_id', columns='product_id', values='score', fill_value=0)

# 3. Compute similarity matrices from train data
user_similarity = pd.DataFrame(
    cosine_similarity(user_item_matrix),
    index=user_item_matrix.index,
    columns=user_item_matrix.index
)
item_similarity = pd.DataFrame(
    cosine_similarity(user_item_matrix.T),
    index=user_item_matrix.columns,
    columns=user_item_matrix.columns
)

# 4. Prepare test users and ground truth dict
users = test_df['user_id'].unique()
test_truth = test_df.groupby('user_id')['product_id'].apply(set).to_dict()

def get_product_details_for_recommendations(recommended_product_ids, cleaned_data):
    recommended_details = cleaned_data[cleaned_data['product_id'].isin(recommended_product_ids)].copy()
    recommended_details = recommended_details.set_index('product_id').loc[recommended_product_ids].reset_index()
    return recommended_details

# 5. Evaluate hybrid CF
alpha = 0.5  # user-user and item-item blending weight
precisions, recalls = [], []

for user in users:
    recs = recommend_items_hybrid(user, user_item_matrix, user_similarity, item_similarity, top_k=5, alpha=alpha)
    detailed_recs = get_product_details_for_recommendations(recs, df)
    print(f"User: {user} Recommendations:\n", detailed_recs[['product_id', 'product_name', 'brand', 'price', 'product_type']])
    truth = test_truth.get(user, set())
    precisions.append(precision_at_k(recs, truth, 5))
    recalls.append(recall_at_k(recs, truth, 5))

print(f"Hybrid CF (alpha={alpha}): Precision@5 = {np.mean(precisions):.4f}")
print(f"Hybrid CF (alpha={alpha}): Recall@5 = {np.mean(recalls):.4f}")
# Out:
# User: user_000 Recommendations:
#    product_id                                       product_name  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum
# 1    prod_35                   Avoskin Ultra Brightening Cream
# 2   prod_237  Dear Me Beauty Dear Me Beauty X KFC Primer Sun...
# 3   prod_725             Nature Republic CALENDULA RELIEF TONER
# 4    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
#
#              brand   price product_type
# 0         SCARLETT   66000        Serum
# 1          AVOSKIN  185900  Moisturizer
# 2   DEAR ME BEAUTY  139000    Sunscreen
# 3  NATURE REPUBLIC  130000        Toner
# 4          AVOSKIN  163900        Toner
# User: user_001 Recommendations:
#    product_id                                       product_name       brand  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...    KIEHL'S
# 1  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...  SOMETHINC
# 2   prod_432                            HANASUI Serum Vitamin C    HANASUI
# 3   prod_609                KLEVERU Sea Buckthorn Cleansing Gel     KLEVERU
# 4   prod_148                       BHUMI C+ Brightening Booster       BHUMI
#
#     price product_type
# 0  100000        Serum
# 1  125000    Sunscreen
# 2   25000        Serum
# 3   77000    Face Wash
# 4  217500        Serum
# User: user_002 Recommendations:
#    product_id                                       product_name     brand  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum  SCARLETT
# 1   prod_339                       ERHA Erha 3 Balancing Toner      ERHA
# 2    prod_46  AVOSKIN YOUR SKIN BAE SERIES Toner Niacinamide...   AVOSKIN
# 3   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck   SKEYNDOR
# 4   prod_220                 COSRX One Step Original Clear Pads     COSRX
#
#      price product_type
# 0    66000        Serum
# 1    82000        Toner
# 2   149000        Toner
# 3  1595000        Serum
# 4   285000        Toner
# User: user_003 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1  prod_1180                    Whitelab Hydrating Face Essence
# 2   prod_550                              Cica Care Gentle Wash
# 3   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner
# 4   prod_159                            Bioderma Photoderm Kid
#
#            brand   price product_type
# 0  THE BODY SHOP  199000    Face Wash
# 1       WHITELAB   68000        Serum
# 2   JARTE BEAUTY   90000    Face Wash
# 3    BIO ESSENCE  159000        Toner
# 4       BIODERMA  363000    Sunscreen
# User: user_004 Recommendations:
#    product_id                                       product_name       brand  \
# 0   prod_162                 Bioderma Photoderm AKN Mat SPF-30     BIODERMA
# 1  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...   SOMETHINC
# 2   prod_432                            HANASUI Serum Vitamin C    HANASUI
# 3   prod_609                KLEVERU Sea Buckthorn Cleansing Gel     KLEVERU
# 4  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...  SOMETHINC
#
#     price product_type
# 0  319000    Sunscreen
# 1  199000        Serum
# 2   25000        Serum
# 3   77000    Face Wash
# 4  125000    Sunscreen
# User: user_005 Recommendations:
#    product_id                                       product_name  \
# 0   prod_408            GLOWINC POTION ACNECORE+ Clear AC Toner
# 1   prod_846   Scarlett Whitening Brightly Ever After Day Cream
# 2   prod_670         Mediheal Tea Tree Biome Blemish Cica Toner
# 3   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30
# 4   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...
#
#             brand   price product_type
# 0  GLOWINC POTION   79000        Toner
# 1        SCARLETT   82500  Moisturizer
# 2        MEDIHEAL  279000        Toner
# 3           RAYOU  115000    Sunscreen
# 4            ERHA  192500  Moisturizer
# User: user_006 Recommendations:
#    product_id                                       product_name  \
# 0   prod_832          SAFI White Expert Purifying Cleanser 50gr
# 1    prod_92  AZARINE Oil Free Brightening Daily Moisturizer...
# 2  prod_1097         Votre Peau Herbal Lavender Facial Cleanser
# 3  prod_1095               VOTRE PEAU Serum Retinol Concentrate
# 4  prod_1054                  The Body Shop Aloe Cream Cleanser
#
#            brand   price product_type
# 0           SAFI   25000    Face Wash
# 1       AZARINE    69000  Moisturizer
# 2     VOTRE PEAU  165000    Face Wash
# 3     VOTRE PEAU  215000        Serum
# 4  THE BODY SHOP  199000    Face Wash
# User: user_007 Recommendations:
#    product_id                                       product_name  \
# 0   prod_339                       ERHA Erha 3 Balancing Toner
# 1   prod_393                         Garnier Sakura Night Cream
# 2   prod_725             Nature Republic CALENDULA RELIEF TONER
# 3   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck
# 4    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
#
#              brand    price product_type
# 0            ERHA     82000        Toner
# 1          GARNIER    32500  Moisturizer
# 2  NATURE REPUBLIC   130000        Toner
# 3         SKEYNDOR  1595000        Serum
# 4          AVOSKIN   163900        Toner
# User: user_008 Recommendations:
#    product_id                                       product_name  \
# 0   prod_393                         Garnier Sakura Night Cream
# 1   prod_725             Nature Republic CALENDULA RELIEF TONER
# 2    prod_46  AVOSKIN YOUR SKIN BAE SERIES Toner Niacinamide...
# 3   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck
# 4    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
#
#              brand    price product_type
# 0          GARNIER    32500  Moisturizer
# 1  NATURE REPUBLIC   130000        Toner
# 2          AVOSKIN   149000        Toner
# 3         SKEYNDOR  1595000        Serum
# 4          AVOSKIN   163900        Toner
# User: user_009 Recommendations:
#    product_id                                       product_name         brand  \
# 0   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner    BIO ESSENCE
# 1  prod_1103                            VT Cosmetics Cica Skin   VT COSMETICS
# 2   prod_430              HanasuiAcne Treatment Gentle Cleanser       HANASUI
# 3   prod_159                            Bioderma Photoderm Kid       BIODERMA
# 4   prod_341                Erha Skin Barrier Face Moisturizer           ERHA
#
#     price product_type
# 0  159000        Toner
# 1  429000        Toner
# 2   21600    Face Wash
# 3  363000    Sunscreen
# 4   86900  Moisturizer
# User: user_010 Recommendations:
#    product_id                                product_name       brand    price  \
# 0   prod_674       Missha Premium Cica Aloe Soothing Gel      MISSHA   159000
# 1   prod_832   SAFI White Expert Purifying Cleanser 50gr        SAFI    25000
# 2   prod_908         SKEYNDOR Timeless Prodigy The Serum    SKEYNDOR  3520000
# 3  prod_1095        VOTRE PEAU Serum Retinol Concentrate  VOTRE PEAU   215000
# 4  prod_1097  Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU   165000
#
#   product_type
# 0  Moisturizer
# 1    Face Wash
# 2        Serum
# 3        Serum
# 4    Face Wash
# User: user_011 Recommendations:
#    product_id                                       product_name  \
# 0   prod_723                    Nature Republic Bee Venom Toner
# 1   prod_846   Scarlett Whitening Brightly Ever After Day Cream
# 2   prod_670         Mediheal Tea Tree Biome Blemish Cica Toner
# 3   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...
# 4   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30
#
#              brand   price product_type
# 0  NATURE REPUBLIC  258000        Toner
# 1         SCARLETT   82500  Moisturizer
# 2         MEDIHEAL  279000        Toner
# 3             ERHA  192500  Moisturizer
# 4            RAYOU  115000    Sunscreen
# User: user_012 Recommendations:
#    product_id                                       product_name      brand  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...   KIEHL'S
# 1   prod_162                 Bioderma Photoderm AKN Mat SPF-30    BIODERMA
# 2  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...  SOMETHINC
# 3   prod_432                            HANASUI Serum Vitamin C   HANASUI
# 4  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...     WARDAH
#
#     price product_type
# 0  100000        Serum
# 1  319000    Sunscreen
# 2  199000        Serum
# 3   25000        Serum
# 4   60100        Serum
# User: user_013 Recommendations:
#    product_id                                      product_name       brand  \
# 0    prod_36  Avoskin PHTE Special Edition Avoskin x Sociolla      AVOSKIN
# 1  prod_1095              VOTRE PEAU Serum Retinol Concentrate  VOTRE PEAU
# 2   prod_576         KIEHLS Ultra Facial Oil-Free Toner 250ml      KIEHL'S
# 3   prod_910                  SKEYNDOR Eternal Intensive Serum   SKEYNDOR
# 4   prod_393                        Garnier Sakura Night Cream     GARNIER
#
#      price product_type
# 0   328900        Toner
# 1   215000        Serum
# 2   470000        Toner
# 3  1045000        Serum
# 4    32500  Moisturizer
# User: user_014 Recommendations:
#    product_id                                product_name         brand  \
# 0    prod_17  ANESSA Perfect UV Sunscreen Skincare Milk         ANESSA
# 1  prod_1103                     VT Cosmetics Cica Skin   VT COSMETICS
# 2   prod_430       HanasuiAcne Treatment Gentle Cleanser       HANASUI
# 3   prod_159                     Bioderma Photoderm Kid       BIODERMA
# 4   prod_341         Erha Skin Barrier Face Moisturizer           ERHA
#
#     price product_type
# 0  199000    Sunscreen
# 1  429000        Toner
# 2   21600    Face Wash
# 3  363000    Sunscreen
# 4   86900  Moisturizer
# User: user_015 Recommendations:
#    product_id                                       product_name  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...
# 1   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml
# 2  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...
# 3   prod_432                            HANASUI Serum Vitamin C
# 4  prod_1055            The Body Shop Lemon Purifying Face Wash
#
#            brand   price product_type
# 0       KIEHL'S   100000        Serum
# 1    BIO ESSENCE  299000        Toner
# 2     SOMETHINC   125000    Sunscreen
# 3       HANASUI    25000        Serum
# 4  THE BODY SHOP  199000    Face Wash
# User: user_016 Recommendations:
#    product_id                                product_name       brand    price  \
# 0   prod_908         SKEYNDOR Timeless Prodigy The Serum    SKEYNDOR  3520000
# 1  prod_1097  Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU   165000
# 2   prod_576   KIEHLS Ultra Facial Oil-Free Toner 250ml      KIEHL'S   470000
# 3  prod_1039         THAYERS Witch Hazel Toner Lavender     THAYERS    230000
# 4   prod_393                  Garnier Sakura Night Cream     GARNIER    32500
#
#   product_type
# 0        Serum
# 1    Face Wash
# 2        Toner
# 3        Toner
# 4  Moisturizer
# User: user_017 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1149                wardah C-Defense Mousse Moisturizer
# 1  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 2   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner
# 3  prod_1090                                   Tulus Hyalutonic
# 4   prod_341                Erha Skin Barrier Face Moisturizer
#
#            brand   price product_type
# 0         WARDAH   55500  Moisturizer
# 1  THE BODY SHOP  199000    Face Wash
# 2    BIO ESSENCE  159000        Toner
# 3          TULUS  199000        Toner
# 4           ERHA   86900  Moisturizer
# User: user_018 Recommendations:
#    product_id                                       product_name      brand  \
# 0   prod_596   KLAIRS Supple Preparation UNSCENTED Facial Toner     KLAIRS
# 1   prod_670         Mediheal Tea Tree Biome Blemish Cica Toner   MEDIHEAL
# 2   prod_189  Bloomka Calendula+vitamin B3 Whitening Facial ...    BLOOMKA
# 3   prod_221                         COSRX Hydrium Watery Toner      COSRX
# 4   prod_993         Somethinc HYALuronic9+ Advanced + B5 Serum  SOMETHINC
#
#     price product_type
# 0  310000        Toner
# 1  279000        Toner
# 2   92000        Toner
# 3   99000        Toner
# 4  115500        Serum
# User: user_019 Recommendations:
#    product_id                           product_name         brand   price  \
# 0   prod_550                  Cica Care Gentle Wash  JARTE BEAUTY   90000
# 1   prod_430  HanasuiAcne Treatment Gentle Cleanser       HANASUI   21600
# 2   prod_335  Erha Truwhite Brightening Face Toner           ERHA  126500
# 3   prod_159                Bioderma Photoderm Kid       BIODERMA  363000
# 4   prod_341    Erha Skin Barrier Face Moisturizer           ERHA   86900
#
#   product_type
# 0    Face Wash
# 1    Face Wash
# 2        Toner
# 3    Sunscreen
# 4  Moisturizer
# User: user_020 Recommendations:
#    product_id                                       product_name       brand  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...    KIEHL'S
# 1   prod_682                                 Momopuri Gel Cream    MOMOPURI
# 2   prod_162                 Bioderma Photoderm AKN Mat SPF-30     BIODERMA
# 3  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...   SOMETHINC
# 4  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...  SOMETHINC
#
#     price product_type
# 0  100000        Serum
# 1  219000  Moisturizer
# 2  319000    Sunscreen
# 3  199000        Serum
# 4  125000    Sunscreen
# User: user_021 Recommendations:
#    product_id                                       product_name       brand  \
# 0   prod_682                                 Momopuri Gel Cream    MOMOPURI
# 1   prod_609                KLEVERU Sea Buckthorn Cleansing Gel     KLEVERU
# 2  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...  SOMETHINC
# 3   prod_432                            HANASUI Serum Vitamin C    HANASUI
# 4   prod_148                       BHUMI C+ Brightening Booster       BHUMI
#
#     price product_type
# 0  219000  Moisturizer
# 1   77000    Face Wash
# 2  125000    Sunscreen
# 3   25000        Serum
# 4  217500        Serum
# User: user_022 Recommendations:
#    product_id                                       product_name     brand  \
# 0   prod_609                KLEVERU Sea Buckthorn Cleansing Gel   KLEVERU
# 1   prod_596   KLAIRS Supple Preparation UNSCENTED Facial Toner    KLAIRS
# 2   prod_670         Mediheal Tea Tree Biome Blemish Cica Toner  MEDIHEAL
# 3   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30     RAYOU
# 4   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...      ERHA
#
#     price product_type
# 0   77000    Face Wash
# 1  310000        Toner
# 2  279000        Toner
# 3  115000    Sunscreen
# 4  192500  Moisturizer
# User: user_023 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1  prod_1103                            VT Cosmetics Cica Skin
# 2   prod_335              Erha Truwhite Brightening Face Toner
# 3  prod_1090                                   Tulus Hyalutonic
# 4   prod_341                Erha Skin Barrier Face Moisturizer
#
#            brand   price product_type
# 0  THE BODY SHOP  199000    Face Wash
# 1   VT COSMETICS  429000        Toner
# 2           ERHA  126500        Toner
# 3          TULUS  199000        Toner
# 4           ERHA   86900  Moisturizer
# User: user_024 Recommendations:
#    product_id                                       product_name         brand  \
# 0   prod_550                              Cica Care Gentle Wash  JARTE BEAUTY
# 1  prod_1103                            VT Cosmetics Cica Skin   VT COSMETICS
# 2   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner    BIO ESSENCE
# 3   prod_159                            Bioderma Photoderm Kid       BIODERMA
# 4   prod_341                Erha Skin Barrier Face Moisturizer           ERHA
#
#     price product_type
# 0   90000    Face Wash
# 1  429000        Toner
# 2  159000        Toner
# 3  363000    Sunscreen
# 4   86900  Moisturizer
# User: user_025 Recommendations:
#    product_id                                       product_name  \
# 0    prod_35                   Avoskin Ultra Brightening Cream
# 1    prod_46  AVOSKIN YOUR SKIN BAE SERIES Toner Niacinamide...
# 2    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
# 3   prod_725             Nature Republic CALENDULA RELIEF TONER
# 4   prod_220                 COSRX One Step Original Clear Pads
#
#              brand   price product_type
# 0          AVOSKIN  185900  Moisturizer
# 1          AVOSKIN  149000        Toner
# 2          AVOSKIN  163900        Toner
# 3  NATURE REPUBLIC  130000        Toner
# 4            COSRX  285000        Toner
# User: user_026 Recommendations:
#    product_id                                       product_name        brand  \
# 0   prod_162                 Bioderma Photoderm AKN Mat SPF-30      BIODERMA
# 1   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml   BIO ESSENCE
# 2  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...    SOMETHINC
# 3  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...       WARDAH
# 4   prod_148                       BHUMI C+ Brightening Booster        BHUMI
#
#     price product_type
# 0  319000    Sunscreen
# 1  299000        Toner
# 2  199000        Serum
# 3   60100        Serum
# 4  217500        Serum
# User: user_027 Recommendations:
#    product_id                                       product_name  \
# 0   prod_908                SKEYNDOR Timeless Prodigy The Serum
# 1  prod_1097         Votre Peau Herbal Lavender Facial Cleanser
# 2  prod_1054                  The Body Shop Aloe Cream Cleanser
# 3    prod_92  AZARINE Oil Free Brightening Daily Moisturizer...
# 4   prod_576          KIEHLS Ultra Facial Oil-Free Toner 250ml
#
#            brand    price product_type
# 0       SKEYNDOR  3520000        Serum
# 1     VOTRE PEAU   165000    Face Wash
# 2  THE BODY SHOP   199000    Face Wash
# 3       AZARINE     69000  Moisturizer
# 4        KIEHL'S   470000        Toner
# User: user_028 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1  prod_1103                            VT Cosmetics Cica Skin
# 2   prod_335              Erha Truwhite Brightening Face Toner
# 3  prod_1090                                   Tulus Hyalutonic
# 4   prod_341                Erha Skin Barrier Face Moisturizer
#
#            brand   price product_type
# 0  THE BODY SHOP  199000    Face Wash
# 1   VT COSMETICS  429000        Toner
# 2           ERHA  126500        Toner
# 3          TULUS  199000        Toner
# 4           ERHA   86900  Moisturizer
# User: user_029 Recommendations:
#    product_id                         product_name     brand   price  \
# 0   prod_859  SCARLETT WHITENING Glowtening Serum  SCARLETT   66000
# 1    prod_35     Avoskin Ultra Brightening Cream    AVOSKIN  185900
# 2   prod_393           Garnier Sakura Night Cream   GARNIER   32500
# 3    prod_45     AVOSKIN Miraculous Retinol Toner   AVOSKIN  199000
# 4   prod_220   COSRX One Step Original Clear Pads     COSRX  285000
#
#   product_type
# 0        Serum
# 1  Moisturizer
# 2  Moisturizer
# 3        Toner
# 4        Toner
# User: user_030 Recommendations:
#    product_id                           product_name     brand   price  \
# 0   prod_430  HanasuiAcne Treatment Gentle Cleanser   HANASUI   21600
# 1   prod_335  Erha Truwhite Brightening Face Toner       ERHA  126500
# 2  prod_1090                       Tulus Hyalutonic     TULUS  199000
# 3   prod_159                Bioderma Photoderm Kid   BIODERMA  363000
# 4   prod_341    Erha Skin Barrier Face Moisturizer       ERHA   86900
#
#   product_type
# 0    Face Wash
# 1        Toner
# 2        Toner
# 3    Sunscreen
# 4  Moisturizer
# User: user_031 Recommendations:
#    product_id                                      product_name       brand  \
# 0    prod_36  Avoskin PHTE Special Edition Avoskin x Sociolla      AVOSKIN
# 1   prod_908               SKEYNDOR Timeless Prodigy The Serum    SKEYNDOR
# 2  prod_1097        Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU
# 3  prod_1095              VOTRE PEAU Serum Retinol Concentrate  VOTRE PEAU
# 4   prod_910                  SKEYNDOR Eternal Intensive Serum   SKEYNDOR
#
#      price product_type
# 0   328900        Toner
# 1  3520000        Serum
# 2   165000    Face Wash
# 3   215000        Serum
# 4  1045000        Serum
# User: user_032 Recommendations:
#    product_id                                   product_name            brand  \
# 0   prod_393                     Garnier Sakura Night Cream          GARNIER
# 1   prod_339                   ERHA Erha 3 Balancing Toner             ERHA
# 2   prod_725         Nature Republic CALENDULA RELIEF TONER  NATURE REPUBLIC
# 3   prod_920  SKEYNDOR Lift Contour Elixir - Face And Neck          SKEYNDOR
# 4   prod_915                  SKEYNDOR Antiox Glowing Serum         SKEYNDOR
#
#      price product_type
# 0    32500  Moisturizer
# 1    82000        Toner
# 2   130000        Toner
# 3  1595000        Serum
# 4  1364000        Serum
# User: user_033 Recommendations:
#    product_id                                       product_name        brand  \
# 0   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml   BIO ESSENCE
# 1  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...   SOMETHINC
# 2  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...    SOMETHINC
# 3  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...       WARDAH
# 4   prod_432                            HANASUI Serum Vitamin C     HANASUI
#
#     price product_type
# 0  299000        Toner
# 1  125000    Sunscreen
# 2  199000        Serum
# 3   60100        Serum
# 4   25000        Serum
# User: user_034 Recommendations:
#    product_id                                       product_name  \
# 0   prod_723                    Nature Republic Bee Venom Toner
# 1   prod_846   Scarlett Whitening Brightly Ever After Day Cream
# 2   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30
# 3   prod_221                         COSRX Hydrium Watery Toner
# 4   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...
#
#              brand   price product_type
# 0  NATURE REPUBLIC  258000        Toner
# 1         SCARLETT   82500  Moisturizer
# 2            RAYOU  115000    Sunscreen
# 3            COSRX   99000        Toner
# 4             ERHA  192500  Moisturizer
# User: user_035 Recommendations:
#    product_id                                       product_name      brand  \
# 0   prod_846   Scarlett Whitening Brightly Ever After Day Cream   SCARLETT
# 1   prod_596   KLAIRS Supple Preparation UNSCENTED Facial Toner     KLAIRS
# 2   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30      RAYOU
# 3   prod_127                    Benton Tea Tree Cleansing Water     BENTON
# 4   prod_993         Somethinc HYALuronic9+ Advanced + B5 Serum  SOMETHINC
#
#     price product_type
# 0   82500  Moisturizer
# 1  310000        Toner
# 2  115000    Sunscreen
# 3  300000    Face Wash
# 4  115500        Serum
# User: user_036 Recommendations:
#    product_id                                       product_name     brand  \
# 0    prod_35                   Avoskin Ultra Brightening Cream    AVOSKIN
# 1    prod_46  AVOSKIN YOUR SKIN BAE SERIES Toner Niacinamide...   AVOSKIN
# 2   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck   SKEYNDOR
# 3   prod_220                 COSRX One Step Original Clear Pads     COSRX
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum  SKEYNDOR
#
#      price product_type
# 0   185900  Moisturizer
# 1   149000        Toner
# 2  1595000        Serum
# 3   285000        Toner
# 4  1364000        Serum
# User: user_037 Recommendations:
#    product_id                                       product_name        brand  \
# 0  prod_1149                wardah C-Defense Mousse Moisturizer       WARDAH
# 1    prod_17         ANESSA Perfect UV Sunscreen Skincare Milk        ANESSA
# 2   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner   BIO ESSENCE
# 3   prod_159                            Bioderma Photoderm Kid      BIODERMA
# 4   prod_341                Erha Skin Barrier Face Moisturizer          ERHA
#
#     price product_type
# 0   55500  Moisturizer
# 1  199000    Sunscreen
# 2  159000        Toner
# 3  363000    Sunscreen
# 4   86900  Moisturizer
# User: user_038 Recommendations:
#    product_id                                       product_name  \
# 0   prod_723                    Nature Republic Bee Venom Toner
# 1   prod_596   KLAIRS Supple Preparation UNSCENTED Facial Toner
# 2   prod_127                    Benton Tea Tree Cleansing Water
# 3   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...
# 4   prod_221                         COSRX Hydrium Watery Toner
#
#              brand   price product_type
# 0  NATURE REPUBLIC  258000        Toner
# 1           KLAIRS  310000        Toner
# 2           BENTON  300000    Face Wash
# 3             ERHA  192500  Moisturizer
# 4            COSRX   99000        Toner
# User: user_039 Recommendations:
#    product_id                                product_name        brand   price  \
# 0   prod_162          Bioderma Photoderm AKN Mat SPF-30      BIODERMA  319000
# 1   prod_173  BIO-ESSENCE 24K Bio-Gold Gold Water 100ml   BIO ESSENCE  299000
# 2   prod_432                     HANASUI Serum Vitamin C     HANASUI    25000
# 3   prod_609         KLEVERU Sea Buckthorn Cleansing Gel      KLEVERU   77000
# 4   prod_148                BHUMI C+ Brightening Booster        BHUMI  217500
#
#   product_type
# 0    Sunscreen
# 1        Toner
# 2        Serum
# 3    Face Wash
# 4        Serum
# User: user_040 Recommendations:
#    product_id                                       product_name        brand  \
# 0    prod_17         ANESSA Perfect UV Sunscreen Skincare Milk        ANESSA
# 1   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner   BIO ESSENCE
# 2   prod_335              Erha Truwhite Brightening Face Toner          ERHA
# 3   prod_159                            Bioderma Photoderm Kid      BIODERMA
# 4   prod_341                Erha Skin Barrier Face Moisturizer          ERHA
#
#     price product_type
# 0  199000    Sunscreen
# 1  159000        Toner
# 2  126500        Toner
# 3  363000    Sunscreen
# 4   86900  Moisturizer
# User: user_041 Recommendations:
#    product_id                                product_name       brand   price  \
# 0  prod_1097  Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU  165000
# 1  prod_1095        VOTRE PEAU Serum Retinol Concentrate  VOTRE PEAU  215000
# 2   prod_576   KIEHLS Ultra Facial Oil-Free Toner 250ml      KIEHL'S  470000
# 3  prod_1039         THAYERS Witch Hazel Toner Lavender     THAYERS   230000
# 4   prod_393                  Garnier Sakura Night Cream     GARNIER   32500
#
#   product_type
# 0    Face Wash
# 1        Serum
# 2        Toner
# 3        Toner
# 4  Moisturizer
# User: user_042 Recommendations:
#    product_id                                       product_name  \
# 0   prod_162                 Bioderma Photoderm AKN Mat SPF-30
# 1   prod_714  Nature Republic California Aloe Cooling Sun Sp...
# 2   prod_432                            HANASUI Serum Vitamin C
# 3  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...
# 4  prod_1055            The Body Shop Lemon Purifying Face Wash
#
#              brand   price product_type
# 0         BIODERMA  319000    Sunscreen
# 1  NATURE REPUBLIC  225000    Sunscreen
# 2         HANASUI    25000        Serum
# 3       SOMETHINC   125000    Sunscreen
# 4    THE BODY SHOP  199000    Face Wash
# User: user_043 Recommendations:
#    product_id                                       product_name      brand  \
# 0    prod_92  AZARINE Oil Free Brightening Daily Moisturizer...   AZARINE
# 1   prod_908                SKEYNDOR Timeless Prodigy The Serum   SKEYNDOR
# 2    prod_36   Avoskin PHTE Special Edition Avoskin x Sociolla     AVOSKIN
# 3   prod_910                   SKEYNDOR Eternal Intensive Serum  SKEYNDOR
# 4   prod_393                         Garnier Sakura Night Cream    GARNIER
#
#      price product_type
# 0    69000  Moisturizer
# 1  3520000        Serum
# 2   328900        Toner
# 3  1045000        Serum
# 4    32500  Moisturizer
# User: user_044 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1   prod_550                              Cica Care Gentle Wash
# 2  prod_1103                            VT Cosmetics Cica Skin
# 3   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner
# 4   prod_341                Erha Skin Barrier Face Moisturizer
#
#            brand   price product_type
# 0  THE BODY SHOP  199000    Face Wash
# 1   JARTE BEAUTY   90000    Face Wash
# 2   VT COSMETICS  429000        Toner
# 3    BIO ESSENCE  159000        Toner
# 4           ERHA   86900  Moisturizer
# User: user_045 Recommendations:
#    product_id                                product_name         brand  \
# 0  prod_1180             Whitelab Hydrating Face Essence      WHITELAB
# 1    prod_17  ANESSA Perfect UV Sunscreen Skincare Milk         ANESSA
# 2   prod_550                       Cica Care Gentle Wash  JARTE BEAUTY
# 3   prod_159                     Bioderma Photoderm Kid       BIODERMA
# 4   prod_341         Erha Skin Barrier Face Moisturizer           ERHA
#
#     price product_type
# 0   68000        Serum
# 1  199000    Sunscreen
# 2   90000    Face Wash
# 3  363000    Sunscreen
# 4   86900  Moisturizer
# User: user_046 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1149                wardah C-Defense Mousse Moisturizer
# 1  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 2   prod_550                              Cica Care Gentle Wash
# 3  prod_1090                                   Tulus Hyalutonic
# 4   prod_341                Erha Skin Barrier Face Moisturizer
#
#            brand   price product_type
# 0         WARDAH   55500  Moisturizer
# 1  THE BODY SHOP  199000    Face Wash
# 2   JARTE BEAUTY   90000    Face Wash
# 3          TULUS  199000        Toner
# 4           ERHA   86900  Moisturizer
# User: user_047 Recommendations:
#    product_id                           product_name         brand   price  \
# 0  prod_1149    wardah C-Defense Mousse Moisturizer        WARDAH   55500
# 1  prod_1180        Whitelab Hydrating Face Essence      WHITELAB   68000
# 2   prod_550                  Cica Care Gentle Wash  JARTE BEAUTY   90000
# 3   prod_430  HanasuiAcne Treatment Gentle Cleanser       HANASUI   21600
# 4   prod_159                Bioderma Photoderm Kid       BIODERMA  363000
#
#   product_type
# 0  Moisturizer
# 1        Serum
# 2    Face Wash
# 3    Face Wash
# 4    Sunscreen
# User: user_048 Recommendations:
#    product_id                                       product_name      brand  \
# 0   prod_609                KLEVERU Sea Buckthorn Cleansing Gel    KLEVERU
# 1   prod_846   Scarlett Whitening Brightly Ever After Day Cream   SCARLETT
# 2   prod_127                    Benton Tea Tree Cleansing Water     BENTON
# 3   prod_189  Bloomka Calendula+vitamin B3 Whitening Facial ...    BLOOMKA
# 4   prod_993         Somethinc HYALuronic9+ Advanced + B5 Serum  SOMETHINC
#
#     price product_type
# 0   77000    Face Wash
# 1   82500  Moisturizer
# 2  300000    Face Wash
# 3   92000        Toner
# 4  115500        Serum
# User: user_049 Recommendations:
#    product_id                                       product_name  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum
# 1   prod_339                       ERHA Erha 3 Balancing Toner
# 2    prod_45                   AVOSKIN Miraculous Retinol Toner
# 3   prod_725             Nature Republic CALENDULA RELIEF TONER
# 4    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
#
#              brand   price product_type
# 0         SCARLETT   66000        Serum
# 1            ERHA    82000        Toner
# 2          AVOSKIN  199000        Toner
# 3  NATURE REPUBLIC  130000        Toner
# 4          AVOSKIN  163900        Toner
# User: user_050 Recommendations:
#    product_id                                       product_name  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum
# 1   prod_339                       ERHA Erha 3 Balancing Toner
# 2   prod_237  Dear Me Beauty Dear Me Beauty X KFC Primer Sun...
# 3    prod_45                   AVOSKIN Miraculous Retinol Toner
# 4    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
#
#             brand   price product_type
# 0        SCARLETT   66000        Serum
# 1           ERHA    82000        Toner
# 2  DEAR ME BEAUTY  139000    Sunscreen
# 3         AVOSKIN  199000        Toner
# 4         AVOSKIN  163900        Toner
# User: user_051 Recommendations:
#    product_id                                       product_name  \
# 0   prod_339                       ERHA Erha 3 Balancing Toner
# 1    prod_46  AVOSKIN YOUR SKIN BAE SERIES Toner Niacinamide...
# 2   prod_725             Nature Republic CALENDULA RELIEF TONER
# 3   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum
#
#              brand    price product_type
# 0            ERHA     82000        Toner
# 1          AVOSKIN   149000        Toner
# 2  NATURE REPUBLIC   130000        Toner
# 3         SKEYNDOR  1595000        Serum
# 4         SKEYNDOR  1364000        Serum
# User: user_052 Recommendations:
#    product_id                                       product_name        brand  \
# 0  prod_1149                wardah C-Defense Mousse Moisturizer       WARDAH
# 1   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner   BIO ESSENCE
# 2   prod_430              HanasuiAcne Treatment Gentle Cleanser      HANASUI
# 3  prod_1090                                   Tulus Hyalutonic        TULUS
# 4   prod_341                Erha Skin Barrier Face Moisturizer          ERHA
#
#     price product_type
# 0   55500  Moisturizer
# 1  159000        Toner
# 2   21600    Face Wash
# 3  199000        Toner
# 4   86900  Moisturizer
# User: user_053 Recommendations:
#    product_id                                       product_name    brand  \
# 0   prod_189  Bloomka Calendula+vitamin B3 Whitening Facial ...  BLOOMKA
# 1   prod_127                    Benton Tea Tree Cleansing Water   BENTON
# 2   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30    RAYOU
# 3   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...     ERHA
# 4   prod_221                         COSRX Hydrium Watery Toner    COSRX
#
#     price product_type
# 0   92000        Toner
# 1  300000    Face Wash
# 2  115000    Sunscreen
# 3  192500  Moisturizer
# 4   99000        Toner
# User: user_054 Recommendations:
#    product_id                                       product_name    brand  \
# 0   prod_609                KLEVERU Sea Buckthorn Cleansing Gel  KLEVERU
# 1   prod_596   KLAIRS Supple Preparation UNSCENTED Facial Toner   KLAIRS
# 2   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30    RAYOU
# 3   prod_127                    Benton Tea Tree Cleansing Water   BENTON
# 4   prod_189  Bloomka Calendula+vitamin B3 Whitening Facial ...  BLOOMKA
#
#     price product_type
# 0   77000    Face Wash
# 1  310000        Toner
# 2  115000    Sunscreen
# 3  300000    Face Wash
# 4   92000        Toner
# User: user_055 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1    prod_17         ANESSA Perfect UV Sunscreen Skincare Milk
# 2   prod_550                              Cica Care Gentle Wash
# 3   prod_430              HanasuiAcne Treatment Gentle Cleanser
# 4   prod_335              Erha Truwhite Brightening Face Toner
#
#            brand   price product_type
# 0  THE BODY SHOP  199000    Face Wash
# 1         ANESSA  199000    Sunscreen
# 2   JARTE BEAUTY   90000    Face Wash
# 3        HANASUI   21600    Face Wash
# 4           ERHA  126500        Toner
# User: user_056 Recommendations:
#    product_id                                       product_name  \
# 0   prod_408            GLOWINC POTION ACNECORE+ Clear AC Toner
# 1   prod_846   Scarlett Whitening Brightly Ever After Day Cream
# 2   prod_127                    Benton Tea Tree Cleansing Water
# 3   prod_189  Bloomka Calendula+vitamin B3 Whitening Facial ...
# 4   prod_993         Somethinc HYALuronic9+ Advanced + B5 Serum
#
#             brand   price product_type
# 0  GLOWINC POTION   79000        Toner
# 1        SCARLETT   82500  Moisturizer
# 2          BENTON  300000    Face Wash
# 3         BLOOMKA   92000        Toner
# 4       SOMETHINC  115500        Serum
# User: user_057 Recommendations:
#    product_id                                      product_name       brand  \
# 0   prod_832         SAFI White Expert Purifying Cleanser 50gr        SAFI
# 1    prod_36  Avoskin PHTE Special Edition Avoskin x Sociolla      AVOSKIN
# 2  prod_1097        Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU
# 3  prod_1095              VOTRE PEAU Serum Retinol Concentrate  VOTRE PEAU
# 4   prod_910                  SKEYNDOR Eternal Intensive Serum   SKEYNDOR
#
#      price product_type
# 0    25000    Face Wash
# 1   328900        Toner
# 2   165000    Face Wash
# 3   215000        Serum
# 4  1045000        Serum
# User: user_058 Recommendations:
#    product_id                                       product_name  \
# 0   prod_832          SAFI White Expert Purifying Cleanser 50gr
# 1    prod_92  AZARINE Oil Free Brightening Daily Moisturizer...
# 2  prod_1054                  The Body Shop Aloe Cream Cleanser
# 3  prod_1095               VOTRE PEAU Serum Retinol Concentrate
# 4   prod_393                         Garnier Sakura Night Cream
#
#            brand   price product_type
# 0           SAFI   25000    Face Wash
# 1       AZARINE    69000  Moisturizer
# 2  THE BODY SHOP  199000    Face Wash
# 3     VOTRE PEAU  215000        Serum
# 4        GARNIER   32500  Moisturizer
# User: user_059 Recommendations:
#    product_id                                       product_name       brand  \
# 0   prod_162                 Bioderma Photoderm AKN Mat SPF-30     BIODERMA
# 1  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...   SOMETHINC
# 2  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...  SOMETHINC
# 3   prod_609                KLEVERU Sea Buckthorn Cleansing Gel     KLEVERU
# 4   prod_148                       BHUMI C+ Brightening Booster       BHUMI
#
#     price product_type
# 0  319000    Sunscreen
# 1  199000        Serum
# 2  125000    Sunscreen
# 3   77000    Face Wash
# 4  217500        Serum
# User: user_060 Recommendations:
#    product_id                                       product_name     brand  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum  SCARLETT
# 1   prod_393                         Garnier Sakura Night Cream   GARNIER
# 2    prod_35                   Avoskin Ultra Brightening Cream    AVOSKIN
# 3    prod_46  AVOSKIN YOUR SKIN BAE SERIES Toner Niacinamide...   AVOSKIN
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum  SKEYNDOR
#
#      price product_type
# 0    66000        Serum
# 1    32500  Moisturizer
# 2   185900  Moisturizer
# 3   149000        Toner
# 4  1364000        Serum
# User: user_061 Recommendations:
#    product_id                                       product_name  \
# 0   prod_609                KLEVERU Sea Buckthorn Cleansing Gel
# 1   prod_408            GLOWINC POTION ACNECORE+ Clear AC Toner
# 2   prod_127                    Benton Tea Tree Cleansing Water
# 3   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...
# 4   prod_993         Somethinc HYALuronic9+ Advanced + B5 Serum
#
#             brand   price product_type
# 0         KLEVERU   77000    Face Wash
# 1  GLOWINC POTION   79000        Toner
# 2          BENTON  300000    Face Wash
# 3            ERHA  192500  Moisturizer
# 4       SOMETHINC  115500        Serum
# User: user_062 Recommendations:
#    product_id                                       product_name     brand  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum  SCARLETT
# 1    prod_35                   Avoskin Ultra Brightening Cream    AVOSKIN
# 2   prod_339                       ERHA Erha 3 Balancing Toner      ERHA
# 3    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...   AVOSKIN
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum  SKEYNDOR
#
#      price product_type
# 0    66000        Serum
# 1   185900  Moisturizer
# 2    82000        Toner
# 3   163900        Toner
# 4  1364000        Serum
# User: user_063 Recommendations:
#    product_id                                   product_name            brand  \
# 0   prod_339                   ERHA Erha 3 Balancing Toner             ERHA
# 1    prod_45               AVOSKIN Miraculous Retinol Toner          AVOSKIN
# 2   prod_920  SKEYNDOR Lift Contour Elixir - Face And Neck          SKEYNDOR
# 3   prod_725         Nature Republic CALENDULA RELIEF TONER  NATURE REPUBLIC
# 4   prod_220             COSRX One Step Original Clear Pads            COSRX
#
#      price product_type
# 0    82000        Toner
# 1   199000        Toner
# 2  1595000        Serum
# 3   130000        Toner
# 4   285000        Toner
# User: user_064 Recommendations:
#    product_id                                       product_name  \
# 0    prod_35                   Avoskin Ultra Brightening Cream
# 1    prod_45                   AVOSKIN Miraculous Retinol Toner
# 2   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck
# 3   prod_725             Nature Republic CALENDULA RELIEF TONER
# 4    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
#
#              brand    price product_type
# 0          AVOSKIN   185900  Moisturizer
# 1          AVOSKIN   199000        Toner
# 2         SKEYNDOR  1595000        Serum
# 3  NATURE REPUBLIC   130000        Toner
# 4          AVOSKIN   163900        Toner
# User: user_065 Recommendations:
#    product_id                                       product_name     brand  \
# 0   prod_609                KLEVERU Sea Buckthorn Cleansing Gel   KLEVERU
# 1   prod_127                    Benton Tea Tree Cleansing Water    BENTON
# 2   prod_189  Bloomka Calendula+vitamin B3 Whitening Facial ...   BLOOMKA
# 3   prod_670         Mediheal Tea Tree Biome Blemish Cica Toner  MEDIHEAL
# 4   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30     RAYOU
#
#     price product_type
# 0   77000    Face Wash
# 1  300000    Face Wash
# 2   92000        Toner
# 3  279000        Toner
# 4  115000    Sunscreen
# User: user_066 Recommendations:
#    product_id                                       product_name  \
# 0   prod_682                                 Momopuri Gel Cream
# 1   prod_714  Nature Republic California Aloe Cooling Sun Sp...
# 2   prod_609                KLEVERU Sea Buckthorn Cleansing Gel
# 3  prod_1055            The Body Shop Lemon Purifying Face Wash
# 4  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...
#
#              brand   price product_type
# 0         MOMOPURI  219000  Moisturizer
# 1  NATURE REPUBLIC  225000    Sunscreen
# 2          KLEVERU   77000    Face Wash
# 3    THE BODY SHOP  199000    Face Wash
# 4           WARDAH   60100        Serum
# User: user_067 Recommendations:
#    product_id                                       product_name  \
# 0   prod_393                         Garnier Sakura Night Cream
# 1   prod_725             Nature Republic CALENDULA RELIEF TONER
# 2    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...
# 3    prod_45                   AVOSKIN Miraculous Retinol Toner
# 4   prod_220                 COSRX One Step Original Clear Pads
#
#              brand   price product_type
# 0          GARNIER   32500  Moisturizer
# 1  NATURE REPUBLIC  130000        Toner
# 2          AVOSKIN  163900        Toner
# 3          AVOSKIN  199000        Toner
# 4            COSRX  285000        Toner
# User: user_068 Recommendations:
#    product_id                                      product_name  \
# 0   prod_408           GLOWINC POTION ACNECORE+ Clear AC Toner
# 1   prod_596  KLAIRS Supple Preparation UNSCENTED Facial Toner
# 2   prod_670        Mediheal Tea Tree Biome Blemish Cica Toner
# 3   prod_127                   Benton Tea Tree Cleansing Water
# 4   prod_221                        COSRX Hydrium Watery Toner
#
#             brand   price product_type
# 0  GLOWINC POTION   79000        Toner
# 1          KLAIRS  310000        Toner
# 2        MEDIHEAL  279000        Toner
# 3          BENTON  300000    Face Wash
# 4           COSRX   99000        Toner
# User: user_069 Recommendations:
#    product_id                                       product_name  \
# 0   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml
# 1   prod_714  Nature Republic California Aloe Cooling Sun Sp...
# 2  prod_1018  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...
# 3   prod_609                KLEVERU Sea Buckthorn Cleansing Gel
# 4  prod_1055            The Body Shop Lemon Purifying Face Wash
#
#              brand   price product_type
# 0      BIO ESSENCE  299000        Toner
# 1  NATURE REPUBLIC  225000    Sunscreen
# 2       SOMETHINC   125000    Sunscreen
# 3          KLEVERU   77000    Face Wash
# 4    THE BODY SHOP  199000    Face Wash
# User: user_070 Recommendations:
#    product_id                                      product_name       brand  \
# 0   prod_674             Missha Premium Cica Aloe Soothing Gel      MISSHA
# 1   prod_908               SKEYNDOR Timeless Prodigy The Serum    SKEYNDOR
# 2    prod_36  Avoskin PHTE Special Edition Avoskin x Sociolla      AVOSKIN
# 3  prod_1097        Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU
# 4   prod_393                        Garnier Sakura Night Cream     GARNIER
#
#      price product_type
# 0   159000  Moisturizer
# 1  3520000        Serum
# 2   328900        Toner
# 3   165000    Face Wash
# 4    32500  Moisturizer
# User: user_071 Recommendations:
#    product_id                                       product_name  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...
# 1   prod_682                                 Momopuri Gel Cream
# 2  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...
# 3   prod_714  Nature Republic California Aloe Cooling Sun Sp...
# 4  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...
#
#              brand   price product_type
# 0         KIEHL'S   100000        Serum
# 1         MOMOPURI  219000  Moisturizer
# 2        SOMETHINC  199000        Serum
# 3  NATURE REPUBLIC  225000    Sunscreen
# 4           WARDAH   60100        Serum
# User: user_072 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1  prod_1180                    Whitelab Hydrating Face Essence
# 2   prod_550                              Cica Care Gentle Wash
# 3   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner
# ...
# 0   prod_859                SCARLETT WHITENING Glowtening Serum
# 1   prod_393                         Garnier Sakura Night Cream
# 2   prod_237  Dear Me Beauty Dear Me Beauty X KFC Primer Sun...
# 3    prod_45                   AVOSKIN Miraculous Retinol Toner
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum
#
#             brand    price product_type
# 0        SCARLETT    66000        Serum
# 1         GARNIER    32500  Moisturizer
# 2  DEAR ME BEAUTY   139000    Sunscreen
# 3         AVOSKIN   199000        Toner
# 4        SKEYNDOR  1364000        Serum
# User: user_977 Recommendations:
#    product_id                                       product_name  \
# 0   prod_162                 Bioderma Photoderm AKN Mat SPF-30
# 1   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml
# 2  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...
# 3  prod_1055            The Body Shop Lemon Purifying Face Wash
# 4   prod_148                       BHUMI C+ Brightening Booster
#
#            brand   price product_type
# 0       BIODERMA  319000    Sunscreen
# 1    BIO ESSENCE  299000        Toner
# 2      SOMETHINC  199000        Serum
# 3  THE BODY SHOP  199000    Face Wash
# 4          BHUMI  217500        Serum
# User: user_978 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1    prod_17         ANESSA Perfect UV Sunscreen Skincare Milk
# 2   prod_335              Erha Truwhite Brightening Face Toner
# 3  prod_1090                                   Tulus Hyalutonic
# 4   prod_159                            Bioderma Photoderm Kid
#
#            brand   price product_type
# 0  THE BODY SHOP  199000    Face Wash
# 1         ANESSA  199000    Sunscreen
# 2           ERHA  126500        Toner
# 3          TULUS  199000        Toner
# 4       BIODERMA  363000    Sunscreen
# User: user_979 Recommendations:
#    product_id                                product_name     brand   price  \
# 0  prod_1180             Whitelab Hydrating Face Essence  WHITELAB   68000
# 1    prod_17  ANESSA Perfect UV Sunscreen Skincare Milk     ANESSA  199000
# 2   prod_335       Erha Truwhite Brightening Face Toner       ERHA  126500
# 3  prod_1090                            Tulus Hyalutonic     TULUS  199000
# 4   prod_341         Erha Skin Barrier Face Moisturizer       ERHA   86900
#
#   product_type
# 0        Serum
# 1    Sunscreen
# 2        Toner
# 3        Toner
# 4  Moisturizer
# User: user_980 Recommendations:
#    product_id                                       product_name  \
# 0   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml
# 1   prod_714  Nature Republic California Aloe Cooling Sun Sp...
# 2  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...
# 3  prod_1055            The Body Shop Lemon Purifying Face Wash
# 4   prod_148                       BHUMI C+ Brightening Booster
#
#              brand   price product_type
# 0      BIO ESSENCE  299000        Toner
# 1  NATURE REPUBLIC  225000    Sunscreen
# 2           WARDAH   60100        Serum
# 3    THE BODY SHOP  199000    Face Wash
# 4            BHUMI  217500        Serum
# User: user_981 Recommendations:
#    product_id                                       product_name  \
# 0   prod_682                                 Momopuri Gel Cream
# 1   prod_162                 Bioderma Photoderm AKN Mat SPF-30
# 2   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml
# 3  prod_1055            The Body Shop Lemon Purifying Face Wash
# 4  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...
#
#            brand   price product_type
# 0       MOMOPURI  219000  Moisturizer
# 1       BIODERMA  319000    Sunscreen
# 2    BIO ESSENCE  299000        Toner
# 3  THE BODY SHOP  199000    Face Wash
# 4         WARDAH   60100        Serum
# User: user_982 Recommendations:
#    product_id                                product_name       brand    price  \
# 0   prod_832   SAFI White Expert Purifying Cleanser 50gr        SAFI    25000
# 1   prod_908         SKEYNDOR Timeless Prodigy The Serum    SKEYNDOR  3520000
# 2  prod_1097  Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU   165000
# 3   prod_393                  Garnier Sakura Night Cream     GARNIER    32500
# 4   prod_910            SKEYNDOR Eternal Intensive Serum   SKEYNDOR   1045000
#
#   product_type
# 0    Face Wash
# 1        Serum
# 2    Face Wash
# 3  Moisturizer
# 4        Serum
# User: user_983 Recommendations:
#    product_id                                       product_name     brand  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum  SCARLETT
# 1   prod_339                       ERHA Erha 3 Balancing Toner      ERHA
# 2    prod_45                   AVOSKIN Miraculous Retinol Toner   AVOSKIN
# 3   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck   SKEYNDOR
# 4    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...   AVOSKIN
#
#      price product_type
# 0    66000        Serum
# 1    82000        Toner
# 2   199000        Toner
# 3  1595000        Serum
# 4   163900        Toner
# User: user_984 Recommendations:
#    product_id                                       product_name  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...
# 1   prod_162                 Bioderma Photoderm AKN Mat SPF-30
# 2   prod_432                            HANASUI Serum Vitamin C
# 3  prod_1055            The Body Shop Lemon Purifying Face Wash
# 4   prod_148                       BHUMI C+ Brightening Booster
#
#            brand   price product_type
# 0       KIEHL'S   100000        Serum
# 1       BIODERMA  319000    Sunscreen
# 2       HANASUI    25000        Serum
# 3  THE BODY SHOP  199000    Face Wash
# 4          BHUMI  217500        Serum
# User: user_985 Recommendations:
#    product_id                                       product_name  \
# 0  prod_1052  The Body Shop Himalayan Charcoal Purifying Fac...
# 1  prod_1180                    Whitelab Hydrating Face Essence
# 2   prod_550                              Cica Care Gentle Wash
# 3   prod_335              Erha Truwhite Brightening Face Toner
# 4   prod_430              HanasuiAcne Treatment Gentle Cleanser
#
#            brand   price product_type
# 0  THE BODY SHOP  199000    Face Wash
# 1       WHITELAB   68000        Serum
# 2   JARTE BEAUTY   90000    Face Wash
# 3           ERHA  126500        Toner
# 4        HANASUI   21600    Face Wash
# User: user_986 Recommendations:
#    product_id                                       product_name        brand  \
# 0   prod_173         BIO-ESSENCE 24K Bio-Gold Gold Water 100ml   BIO ESSENCE
# 1  prod_1003  SOMETHINC 10% Niacinamide + Moisture Sabi Beet...    SOMETHINC
# 2   prod_609                KLEVERU Sea Buckthorn Cleansing Gel      KLEVERU
# 3  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...       WARDAH
# 4   prod_148                       BHUMI C+ Brightening Booster        BHUMI
#
#     price product_type
# 0  299000        Toner
# 1  199000        Serum
# 2   77000    Face Wash
# 3   60100        Serum
# 4  217500        Serum
# User: user_987 Recommendations:
#    product_id                                       product_name  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...
# 1   prod_682                                 Momopuri Gel Cream
# 2   prod_714  Nature Republic California Aloe Cooling Sun Sp...
# 3   prod_609                KLEVERU Sea Buckthorn Cleansing Gel
# 4   prod_148                       BHUMI C+ Brightening Booster
#
#              brand   price product_type
# 0         KIEHL'S   100000        Serum
# 1         MOMOPURI  219000  Moisturizer
# 2  NATURE REPUBLIC  225000    Sunscreen
# 3          KLEVERU   77000    Face Wash
# 4            BHUMI  217500        Serum
# User: user_988 Recommendations:
#    product_id                                      product_name  \
# 0   prod_609               KLEVERU Sea Buckthorn Cleansing Gel
# 1   prod_408           GLOWINC POTION ACNECORE+ Clear AC Toner
# 2   prod_596  KLAIRS Supple Preparation UNSCENTED Facial Toner
# 3   prod_825          Rayou x Rahasia Gadis Dailyscreen SPF 30
# 4   prod_993        Somethinc HYALuronic9+ Advanced + B5 Serum
#
#             brand   price product_type
# 0         KLEVERU   77000    Face Wash
# 1  GLOWINC POTION   79000        Toner
# 2          KLAIRS  310000        Toner
# 3           RAYOU  115000    Sunscreen
# 4       SOMETHINC  115500        Serum
# User: user_989 Recommendations:
#    product_id                                       product_name  \
# 0   prod_393                         Garnier Sakura Night Cream
# 1   prod_237  Dear Me Beauty Dear Me Beauty X KFC Primer Sun...
# 2   prod_725             Nature Republic CALENDULA RELIEF TONER
# 3    prod_45                   AVOSKIN Miraculous Retinol Toner
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum
#
#              brand    price product_type
# 0          GARNIER    32500  Moisturizer
# 1   DEAR ME BEAUTY   139000    Sunscreen
# 2  NATURE REPUBLIC   130000        Toner
# 3          AVOSKIN   199000        Toner
# 4         SKEYNDOR  1364000        Serum
# User: user_990 Recommendations:
#    product_id                                product_name       brand    price  \
# 0   prod_674       Missha Premium Cica Aloe Soothing Gel      MISSHA   159000
# 1   prod_832   SAFI White Expert Purifying Cleanser 50gr        SAFI    25000
# 2   prod_908         SKEYNDOR Timeless Prodigy The Serum    SKEYNDOR  3520000
# 3  prod_1097  Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU   165000
# 4   prod_910            SKEYNDOR Eternal Intensive Serum   SKEYNDOR   1045000
#
#   product_type
# 0  Moisturizer
# 1    Face Wash
# 2        Serum
# 3    Face Wash
# 4        Serum
# User: user_991 Recommendations:
#    product_id                                       product_name         brand  \
# 0  prod_1149                wardah C-Defense Mousse Moisturizer        WARDAH
# 1    prod_17         ANESSA Perfect UV Sunscreen Skincare Milk         ANESSA
# 2  prod_1103                            VT Cosmetics Cica Skin   VT COSMETICS
# 3   prod_174  BIO-ESSENCE Bio-White Advanced Whitening Refiner    BIO ESSENCE
# 4   prod_341                Erha Skin Barrier Face Moisturizer           ERHA
#
#     price product_type
# 0   55500  Moisturizer
# 1  199000    Sunscreen
# 2  429000        Toner
# 3  159000        Toner
# 4   86900  Moisturizer
# User: user_992 Recommendations:
#    product_id                                       product_name       brand  \
# 0   prod_908                SKEYNDOR Timeless Prodigy The Serum    SKEYNDOR
# 1    prod_36   Avoskin PHTE Special Edition Avoskin x Sociolla      AVOSKIN
# 2  prod_1097         Votre Peau Herbal Lavender Facial Cleanser  VOTRE PEAU
# 3    prod_92  AZARINE Oil Free Brightening Daily Moisturizer...    AZARINE
# 4   prod_910                   SKEYNDOR Eternal Intensive Serum   SKEYNDOR
#
#      price product_type
# 0  3520000        Serum
# 1   328900        Toner
# 2   165000    Face Wash
# 3    69000  Moisturizer
# 4  1045000        Serum
# User: user_993 Recommendations:
#    product_id                                      product_name  \
# 0   prod_408           GLOWINC POTION ACNECORE+ Clear AC Toner
# 1   prod_596  KLAIRS Supple Preparation UNSCENTED Facial Toner
# 2   prod_127                   Benton Tea Tree Cleansing Water
# 3   prod_993        Somethinc HYALuronic9+ Advanced + B5 Serum
# 4   prod_221                        COSRX Hydrium Watery Toner
#
#             brand   price product_type
# 0  GLOWINC POTION   79000        Toner
# 1          KLAIRS  310000        Toner
# 2          BENTON  300000    Face Wash
# 3       SOMETHINC  115500        Serum
# 4           COSRX   99000        Toner
# User: user_994 Recommendations:
#    product_id                                       product_name  \
# 0   prod_570  KIEHLS Clearly Corrective Accelerated Clarity ...
# 1   prod_714  Nature Republic California Aloe Cooling Sun Sp...
# 2  prod_1124  Wardah Crystal Secret Dark Spot & Brightening ...
# 3   prod_609                KLEVERU Sea Buckthorn Cleansing Gel
# 4   prod_148                       BHUMI C+ Brightening Booster
#
#              brand   price product_type
# 0         KIEHL'S   100000        Serum
# 1  NATURE REPUBLIC  225000    Sunscreen
# 2           WARDAH   60100        Serum
# 3          KLEVERU   77000    Face Wash
# 4            BHUMI  217500        Serum
# User: user_995 Recommendations:
#    product_id                                       product_name  \
# 0   prod_846   Scarlett Whitening Brightly Ever After Day Cream
# 1   prod_408            GLOWINC POTION ACNECORE+ Clear AC Toner
# 2   prod_127                    Benton Tea Tree Cleansing Water
# 3   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30
# 4   prod_331  Erha Age Corrector Night Cream 30g - Niacinami...
#
#             brand   price product_type
# 0        SCARLETT   82500  Moisturizer
# 1  GLOWINC POTION   79000        Toner
# 2          BENTON  300000    Face Wash
# 3           RAYOU  115000    Sunscreen
# 4            ERHA  192500  Moisturizer
# User: user_996 Recommendations:
#    product_id                                       product_name     brand  \
# 0    prod_35                   Avoskin Ultra Brightening Cream    AVOSKIN
# 1    prod_46  AVOSKIN YOUR SKIN BAE SERIES Toner Niacinamide...   AVOSKIN
# 2    prod_45                   AVOSKIN Miraculous Retinol Toner   AVOSKIN
# 3   prod_220                 COSRX One Step Original Clear Pads     COSRX
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum  SKEYNDOR
#
#      price product_type
# 0   185900  Moisturizer
# 1   149000        Toner
# 2   199000        Toner
# 3   285000        Toner
# 4  1364000        Serum
# User: user_997 Recommendations:
#    product_id                            product_name            brand   price  \
# 0   prod_859     SCARLETT WHITENING Glowtening Serum         SCARLETT   66000
# 1   prod_339            ERHA Erha 3 Balancing Toner             ERHA    82000
# 2    prod_45        AVOSKIN Miraculous Retinol Toner          AVOSKIN  199000
# 3   prod_725  Nature Republic CALENDULA RELIEF TONER  NATURE REPUBLIC  130000
# 4   prod_220      COSRX One Step Original Clear Pads            COSRX  285000
#
#   product_type
# 0        Serum
# 1        Toner
# 2        Toner
# 3        Toner
# 4        Toner
# User: user_998 Recommendations:
#    product_id                                       product_name  \
# 0   prod_723                    Nature Republic Bee Venom Toner
# 1   prod_825           Rayou x Rahasia Gadis Dailyscreen SPF 30
# 2   prod_189  Bloomka Calendula+vitamin B3 Whitening Facial ...
# 3   prod_221                         COSRX Hydrium Watery Toner
# 4   prod_993         Somethinc HYALuronic9+ Advanced + B5 Serum
#
#              brand   price product_type
# 0  NATURE REPUBLIC  258000        Toner
# 1            RAYOU  115000    Sunscreen
# 2          BLOOMKA   92000        Toner
# 3            COSRX   99000        Toner
# 4        SOMETHINC  115500        Serum
# User: user_999 Recommendations:
#    product_id                                       product_name     brand  \
# 0   prod_859                SCARLETT WHITENING Glowtening Serum  SCARLETT
# 1   prod_393                         Garnier Sakura Night Cream   GARNIER
# 2    prod_59  Avoskin YOUR SKIN BAE SERIES Toner Niacinamide...   AVOSKIN
# 3   prod_920      SKEYNDOR Lift Contour Elixir - Face And Neck   SKEYNDOR
# 4   prod_915                      SKEYNDOR Antiox Glowing Serum  SKEYNDOR
#
#      price product_type
# 0    66000        Serum
# 1    32500  Moisturizer
# 2   163900        Toner
# 3  1595000        Serum
# 4  1364000        Serum
# Hybrid CF (alpha=0.5): Precision@5 = 0.6000
# Hybrid CF (alpha=0.5): Recall@5 = 0.7500

# %%
sample_user = users[220]
recommended_ids = recommend_items_hybrid(sample_user, user_item_matrix, user_similarity, item_similarity, top_k=5, alpha=0.5)
detailed_recs = get_product_details_for_recommendations(recommended_ids, df)
print(detailed_recs[['product_name', 'product_type', 'brand', 'price']])
# Out:
#                                         product_name product_type       brand  \
# 0                                 Momopuri Gel Cream  Moisturizer    MOMOPURI
# 1                 Bioderma Photoderm AKN Mat SPF-30     Sunscreen    BIODERMA
# 2                KLEVERU Sea Buckthorn Cleansing Gel    Face Wash     KLEVERU
# 3                            HANASUI Serum Vitamin C        Serum    HANASUI
# 4  SOMETHINC Glowing Up Sunscreen Stick SPF 50+ P...    Sunscreen  SOMETHINC
#
#     price
# 0  219000
# 1  319000
# 2   77000
# 3   25000
# 4  125000
